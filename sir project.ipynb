# %%
import numpy as np
import pandas as pd
df=pd.read_csv(r"C:\Users\maman\Downloads\Telegram Desktop\car_dataset.csv")
df
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front  88.60  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# ..  ..  ...          ...     ...    ...   ...          ...  ...    ...    ...
# 199 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 200 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
# 201 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 202 -1   95        volvo  diesel  turbo  four        sedan  rwd  front  109.1
# 203 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
#
# ...

# %%
df.drop("3",axis=1,inplace=True)
df
# Out:
#        ?  alfa-romero     gas    std   two  convertible  rwd  front  88.60  \
# 0      ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1      ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    164         audi     gas    std  four        sedan  4wd  front   99.4
# 4      ?         audi     gas    std   two        sedan  fwd  front   99.8
# ..   ...          ...     ...    ...   ...          ...  ...    ...    ...
# 199   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 200   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
# 201   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 202   95        volvo  diesel  turbo  four        sedan  rwd  front  109.1
# 203   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
#
# ...

# %%
df=df.drop("?",axis=1)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df=df.drop("?",axis=1)
#       2 df
#
# File ~\AppData\Local\Programs\Python\Python39-32\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39-32\lib\site-packages\pandas\core\frame.py:4906, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4774 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4775 def drop(
#    4776     self,
#    (...)
# ...

# %%
df.columns = [ "Brand", "Fuel Type", "Aspiration", "Num of Doors", "Body Style", "Drive Wheels", "Engine Location", "Wheelbase", "Length", "Width", "Height", "Curb Weight", "Engine Type", "Num of Cylinders", "Engine Size", "Fuel System", "Bore", "Stroke", "Compression Ratio", "Horsepower","Peak RPM", "City"," MPG", "Highway MPG", "Price"]
df
# Out:
#      Brand    Fuel Type Aspiration Num of Doors Body Style Drive Wheels  \
# 0        3  alfa-romero        gas          std        two  convertible
# 1        1  alfa-romero        gas          std        two    hatchback
# 2        2         audi        gas          std       four        sedan
# 3        2         audi        gas          std       four        sedan
# 4        2         audi        gas          std        two        sedan
# ..     ...          ...        ...          ...        ...          ...
# 199     -1        volvo        gas          std       four        sedan
# 200     -1        volvo        gas        turbo       four        sedan
# 201     -1        volvo        gas          std       four        sedan
# 202     -1        volvo     diesel        turbo       four        sedan
# 203     -1        volvo        gas        turbo       four        sedan
#
#     Engine Location Wheelbase  Length  Width  ...  Fuel System  Bore  Stroke  \
# ...

# %%
df.replace("?",np.nan,inplace=True)
df
# Out:
#      Brand    Fuel Type Aspiration Num of Doors Body Style Drive Wheels  \
# 0        3  alfa-romero        gas          std        two  convertible
# 1        1  alfa-romero        gas          std        two    hatchback
# 2        2         audi        gas          std       four        sedan
# 3        2         audi        gas          std       four        sedan
# 4        2         audi        gas          std        two        sedan
# ..     ...          ...        ...          ...        ...          ...
# 199     -1        volvo        gas          std       four        sedan
# 200     -1        volvo        gas        turbo       four        sedan
# 201     -1        volvo        gas          std       four        sedan
# 202     -1        volvo     diesel        turbo       four        sedan
# 203     -1        volvo        gas        turbo       four        sedan
#
#     Engine Location Wheelbase  Length  Width  ...  Fuel System  Bore  Stroke  \
# ...

# %%
df.isnull().sum()
# Out:
# 3              0
# alfa-romero    0
# gas            0
# std            0
# two            2
# convertible    0
# rwd            0
# front          0
# 88.60          0
# 168.80         0
# 64.10          0
# 48.80          0
# 2548           0
# dohc           0
# four           0
# 130            0
# mpfi           0
# 3.47           4
# 2.68           4
# 9.00           0
# 111            2
# 5000           2
# 21             0
# 27             0
# 13495          4
# dtype: int64

# %%
df["Num of Doors"].replace(np.nan,"two",inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39-32\lib\site-packages\pandas\core\nanops.py:1603, in _ensure_numeric(x)
#    1602 try:
# -> 1603     x = float(x)
#    1604 except (TypeError, ValueError):
#    1605     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: '...'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39-32\lib\site-packages\pandas\core\nanops.py:1607, in _ensure_numeric(x)
#    1606 try:
# -> 1607     x = complex(x)
#    1608 except ValueError as err:
#    1609     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39-32\lib\site-packages\pandas\core\indexes\base.py:3361, in Index.get_loc(self, key, method, tolerance)
#    3360 try:
# -> 3361     return self._engine.get_loc(casted_key)
#    3362 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python39-32\lib\site-packages\pandas\_libs\index.pyx:76, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python39-32\lib\site-packages\pandas\_libs\index.pyx:108, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Bore'
#
# ...
